# %%
import os, sys
sys.path.insert(0, os.path.abspath('..'))

# %%
import nanohublib.tool
from gui import *
from gui2 import *

# %% [markdown]
# # Composite Laminate Analysis
# Uses basic laminate theory to estimate effective laminate properties and residual stresses, strains and deformations due to thermal loading.
#
# https://nanohub.org/tools/complam

# %%
complam_menu
# Out:
# Tab(children=(Group(children=(HTML(value="<p   style='background-color: #DCDCDC; font-size: 150%; padding: 5px…

# %%
tf
# Out:
# Number(children=(HTML(value='<div data-toggle="popover" title="Final Temperature\nValues must be in units of d…

# %%
mymenu
# Out:
# Group(children=(Group(children=(HTML(value="<p   style='background-color: #DCDCDC; font-size: 150%; padding: 5…

# %%
complam_menu2
# Out:
# Group(children=(Group(children=(Group(children=(HTML(value="<p   style='background-color: #DCDCDC; font-size: …

# %%
from nanohublib.ui import Checkbox, Text, Radiobuttons, Togglebuttons
x = Checkbox(name="MyCheckBox", description="This is my checkbox example.", value=True, width='20%')

# %%
x
# Out:
# Checkbox(children=(HTML(value='<div data-toggle="popover" title="This is my checkbox example." data-container=…

# %%
t = Text(name="Text Field", description='My text field descriptiopn', value='#####')
t
# Out:
# Text(children=(HTML(value='<div data-toggle="popover" title="My text field descriptiopn" data-container="body"…

# %%
r = Radiobuttons(name='radio', description='My Radio Buttons', options=['AM', 'FM'], value='FM')
r
# Out:
# Radiobuttons(children=(HTML(value='<div data-toggle="popover" title="My Radio Buttons" data-container="body">r…

# %%
import ipywidgets as widgets

# %%
list = ['P0', 'P1', 'P2', 'P3', 'P4']
children = [widgets.Text(description=name) for name in list]
tab = widgets.Tab(children=children)
tab
# Out:
# Tab(children=(Text(value='', description='P0'), Text(value='', description='P1'), Text(value='', description='…

# %%
tab.visible = True

# %%
w = widgets.HTML("FDOO")

# %%
w
# Out:
# HTML(value='FDOO')

# %%
w.disabled
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 w.disabled
#
# AttributeError: 'HTML' object has no attribute 'disabled'

# %%
x = {}
x[0] = 'foo'
x.values()
# Out:
# dict_values(['foo'])
