# %%
import os,sys
sys.path.insert(0, os.path.abspath('..'))
from nanohublib.ui import PathSelector

# %% [markdown]
# The PathSelector widget allows the user to choose a path in the server (container).  It cannot access files
# from the user's computer.

# %%
p = PathSelector('./')
p
# Out:
# Accordion(children=(SelectMultiple(options=(('[..]', '..'), ('[__pycache__]', '__pycache__'), ('[infiles]', 'i…

# %%
p.value
# Out:
# '/Users/denphi/Documents/Github/hublib/examples'

# %%
p.visible=False

# %%
p.visible=True
