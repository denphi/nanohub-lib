# %%
import os,sys
sys.path.insert(0, os.path.abspath('..'))
import ipywidgets as w
from nanohublib.ui import RunCommand

# %%
def my_start(s):
    rname = s.make_rname(cmd.value)
    s.run(cmd.value, rname)

# %%
# after the run finished, optionally do something
# with the output
def read_data(s, rdir):
    # any files written will be in rdir
    # we could use those to plot or something...
    pass

# %%
cmd = w.Text(
    placeholder='Command to execute',
    description='Command:'
)
cmd
# Out:
# Text(value='', description='Command:', placeholder='Command to execute')

# %%
rc = RunCommand(start_func=my_start, done_func=read_data, cachename='Runtest', cachedir='/tmp')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 rc = RunCommand(start_func=my_start, done_func=read_data, cachename='Runtest', cachedir='/tmp')
#
# File ~/Documents/Github/hublib/nanohublib/ui/command.py:120, in RunCommand.__init__(self, label, tooltip, start_func, done_func, outcb, width, cachename, cachedir, cachecb, showcache)
#     118 if not os.path.isdir(self.cachedir):
#     119     os.makedirs(self.cachedir)
# --> 120 memory = Memory(cachedir=self.cachetabdir, verbose=0)
#     122 @memory.cache
#     123 def make_rname(*args):
#     124     # uuid should be unique, but check just in case
#     125     while True:
#
# TypeError: Memory.__init__() got an unexpected keyword argument 'cachedir'

# %%
display(rc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 display(rc)
#
# NameError: name 'rc' is not defined
