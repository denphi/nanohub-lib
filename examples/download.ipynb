# %% [markdown]
# # Download Widget

# %%
import os,sys
sys.path.insert(0, os.path.abspath('..'))
from nanohublib.ui import FileUpload, Download

# %%
Download('wire.data')
# Out:
# HTML(value='\n        <a href="wire.data" download="wire.data" class="p-Widget jupyter-widgets jupyter-button …

# %%
Download('wire.data', style='info')
# Out:
# HTML(value='\n        <a href="wire.data" download="wire.data" class="p-Widget jupyter-widgets jupyter-button …

# %%
Download('wire.data', style='success', icon='fa-arrow-circle-down')
# Out:
# Button(button_style='success', description='wire.data', icon='arrow-circle-down', style=ButtonStyle(), tooltip…

# %%
Download('wire.data', style='warning', icon='fa-cloud-download', tooltip='DOWNLOAD FILE')
# Out:
# Button(button_style='warning', description='wire.data', icon='cloud-download', style=ButtonStyle(), tooltip='D…

# %%
Download('wire.data', label='Download', icon='fa-download', tooltip='DOWNLOAD FILE')
# Out:
# Button(description='Download', icon='download', style=ButtonStyle(), tooltip='DOWNLOAD FILE')

# %%
# ipywidget compatibility

from ipywidgets import HBox

d1 = Download('wire.data', style='success', icon='fa-arrow-circle-down')
d2 = Download('wire.data', label='Download', icon='fa-download', tooltip='DOWNLOAD FILE')

HBox([d1.w, d2.w])
