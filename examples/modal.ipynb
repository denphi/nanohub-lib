# %% [markdown]
# # Modal Widget

# %%
import os,sys
sys.path.insert(0, os.path.abspath('..'))
from nanohublib.ui import Modal

# %%
def modal_callback(val):
    print("Modal Dialog Returned", val)

# %%
Modal(body="This is a test modal dialog.",
      title='TEST DIALOG',
      buttons=['CANCEL', 'OK'], 
      cb=modal_callback)
# Out:
# <style type="text/css">
#
# .modal-dialog {
#     width: 50%;
# }

# %%
Modal(body="This is a test modal dialog.",
      title='TEST DIALOG',
      buttons=['CANCEL', 'OK'],
      primary='CANCEL',
      cb=modal_callback)
# Out:
# <style type="text/css">
#
# .modal-dialog {
#     width: 50%;
# }

# %%
Modal(body="This is a test modal dialog.",
      title='TEST DIALOG',
      buttons=['CANCEL', 'OK'],
      primary=1,
      cb=modal_callback)
# Out:
# <style type="text/css">
#
# .modal-dialog {
#     width: 50%;
# }
