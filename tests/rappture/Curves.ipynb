# %%
from __future__ import print_function
import pytest
import os, sys
import numpy as np

sys.path.insert(0, os.path.abspath('../../..'))
import nanohublib.rappture as rappture
from nanohublib import ureg, Q_

# %%
io = rappture.RapXML('curve.xml')

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import matplotlib

# %%
fig, axs = plt.subplots(1,2)
io['output.curve(single)'].plot(ax=axs[0]);
io['output.curve(single)'].plot(ax=axs[1]);
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
help(io['output.curve(single)'].plot)

# %%
io['output.curve(single)'].plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
curve = io['output.curve(single)']
curve.plot()

# %%
out = io['output']
out['curve(single)'].plot()

# %%
io['output.curve(single)'].plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
io['output.curve(multi1)'].plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
io

# %%
io['output.curve(scatterplot)'].plot()
