# %%
from __future__ import print_function
import pytest
import os, sys
import numpy as np

sys.path.insert(0, os.path.abspath('../../..'))
import nanohublib.rappture as rappture
from nanohublib import ureg, Q_

# %%
io = rappture.RapXML('basic.xml')

# %%
io['tool.command'].xml()
# Out:
# <command>@tool/path/to/executable @driver</command>

# %%
io['input.number(foo)'] = 123.456

# %%
io.xml()
# Out:
# <run>
#   <tool>
#     <title>Name of the tool</title>
#     <about>Description and credits</about>
#     <command>@tool/path/to/executable @driver</command>
#     <limits>
#       <cputime>900</cputime>
#     </limits>
#     <action><label>Simulate</label></action>
#     <layout>xxx</layout>
#     <control>xxx</control>
#     <uq>true</uq>
#     <analyzer>xxx</analyzer>
#     <reportJobFailures>1</reportJobFailures>
#   </tool>
# <input><number id="foo">123.456</number></input></run>

# %%
io['input.number(abc).default'] = 1999

# %%
io['input.number(abc).units'] = 'm'

# %%
io.xml()
# Out:
# <run>
#   <tool>
#     <title>Name of the tool</title>
#     <about>Description and credits</about>
#     <command>@tool/path/to/executable @driver</command>
#     <limits>
#       <cputime>900</cputime>
#     </limits>
#     <action><label>Simulate</label></action>
#     <layout>xxx</layout>
#     <control>xxx</control>
#     <uq>true</uq>
#     <analyzer>xxx</analyzer>
#     <reportJobFailures>1</reportJobFailures>
#   </tool>
# <input><number id="foo">123.456</number><number id="abc"><default>1999</default><units>m</units></number></input></run>

# %%
io['input.number(abc).units'].value
# Out:
# 'm'

# %%
io['input.number(abc).current'] = '100 cm'

# %%
io['input.number(abc).current'].value
# Out:
# 1.0 <Unit('meter')>

# %%
io['input.number(abc).current'] = '5 yards'
io['input.number(abc).current'].value
# Out:
# 4.572 <Unit('meter')>

# %%
io['input.number(abc).current'].value
# Out:
# 4.572 <Unit('meter')>

# %%
io['input.number(abc).current'].magnitude
# Out:
# 4.572

# %%
io['input.number(abc).current'].units
# Out:
# <Unit('meter')>

# %%
val =  io['input.number(abc).current'].value
print('Magnitude is', val.m, 'and units are', val.u)
# Out:
# Magnitude is 4.572 and units are meter

# %%
val.to('mm')
# Out:
# 4572.0 <Unit('millimeter')>

# %%
io['input.number(abc)'].value
# Out:
# 4.572 <Unit('meter')>

# %%
io['input.number(abc)'] = 17

# %%
io['input.number(abc)'].value
# Out:
# 17 <Unit('meter')>

# %%
print(io.xml())
# Out:
# <run>
#   <tool>
#     <title>Name of the tool</title>
#     <about>Description and credits</about>
#     <command>@tool/path/to/executable @driver</command>
#     <limits>
#       <cputime>900</cputime>
#     </limits>
#     <action><label>Simulate</label></action>
#     <layout>xxx</layout>
#     <control>xxx</control>
#     <uq>true</uq>
#     <analyzer>xxx</analyzer>
#     <reportJobFailures>1</reportJobFailures>
#   </tool>
# <input><number id="foo">123.456</number><number id="abc"><default>1999</default><units>m</units><current>17</current></number></input></run>
