# %%
from __future__ import print_function
import pytest
import os, sys
import numpy as np

sys.path.insert(0, os.path.abspath('../../..'))
import nanohublib.rappture as rappture
from nanohublib import ureg, Q_

# %%
from IPython.display import display, Image

# %%
io = rappture.RapXML('circuits.xml')

# %%
io['input.image.current'].value

# %%
val = io['input.image'].value

# %%
val.width=500
val

# %%
Image(val.data, width=400)

# %%
ref = open('circuits.jpg', 'rb').read()
io['input.image.current'] = ref
val = io['input.image.current'].value
val

# %%
io = rappture.RapXML('image_test.xml')

# %%
io.inputs()
# Out:
# ## INPUTS
#                       Label                              Description
# Path
# input.image           Image           Input image that gets rotated.
# input.number(angle)  Rotate  Rotate image by this amount in degrees.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 io.inputs()
#
# TypeError: 'DataFrame' object is not callable

# %%
v = io['input.image'].value
v

# %%
v.width=500
v

# %%
display(v, val)

# %%
io['output.image(outi)'].value
