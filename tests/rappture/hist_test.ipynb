# %%
from __future__ import print_function
import pytest
import os, sys
import numpy as np

sys.path.insert(0, os.path.abspath('../../..'))
import nanohublib.rappture as rappture
from nanohublib import ureg, Q_

# %% [markdown]
# # Histogram Example
#
# This code loads in the output of a run from the Rappture zoo of examples.
#
# https://nanohub.org/infrastructure/rappture/browser/trunk/examples/zoo/histogram

# %%
io = rappture.RapXML('hist_run.xml')

# %%
io
# Out:
# ## INPUTS
#                                   Label  \
# Path
# input.integer(points)  Number of points
#
#                                                              Description
# Path
# input.integer(points)  Determines the number of data points in all ou...
# ## OUTPUTS
#                                                 Label               Group  \
# Path
# output.histogram(example)              Single dataset
# output.histogram(single)             Single histogram
# output.histogram(multi1.8)               Factor a=1.8  Multiple histogram
# output.histogram(multi2)                   Factor a=2  Multiple histogram
# output.histogram(namevalue)      Name value histogram
# output.histogram(width)      Variable-Width histogram
#
#                                                                    Description
# Path
# output.histogram(example)            This is an example of a single histogram.
# output.histogram(single)             This is an example of a single histogram.
# output.histogram(multi1.8)   This is an example of a multiple histograms on...
# output.histogram(multi2)     This is an example of a multiple histograms on...
# output.histogram(namevalue)      This is an example of a name value histogram.
# output.histogram(width)              This is an example of an <xhw> histogram.

# %%
# %matplotlib widget
io['output.histogram(example)'].plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Here is what Rappture outputs:
#
# <img  src="Selection_035.png" align="left"/>

# %%
io['output.histogram(example)'].xml()
# Out:
# <histogram id="example">
#             <about>
#                 <label>Single dataset</label>
#                 <description>This is an example of a single histogram.</description>
#             </about>
#             <xaxis>
#                 <label>Time</label>
#                 <description>Time during the experiment.</description>
#                 <units>s</units>
#                 <marker>
#                     <at>5</at>
#                     <label>Look here</label>
#                     <style>-foreground red -linewidth 2</style>
#                 </marker>
#             </xaxis>
#             <yaxis>
#                 <label>Voltage v(11)</label>
#                 <description>Output from the amplifier.</description>
#                 <units>V</units>
#             </yaxis>
#             <component>
#                 <xy>1 0.99
#        2 0.34
#        4 0.57
#        6 0.22
#        7 0.11</xy>
#             </component>
#         </histogram>

# %%
io['output.histogram(single)'].plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Here is Rappture's output for the same data:
#
#
# <img  src="Selection_036.png" align="left"/>

# %% [markdown]
# Just like Curves, Histograms can have a group id, so they can be plotted together.  Here they are seperated

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(1,2)
io['output.histogram(multi1.8)'].plot(single=True, ax=axs[0])
io['output.histogram(multi2)'].plot(single=True, ax=axs[1])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Plot them both together like this:

# %%
io['output.histogram(multi2)'].plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# If you prefer them stacked...

# %%
io['output.histogram(multi2)'].plot(stacked=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Here is what Rappture does, which seems VERY wrong. It looks like a stacked barchart, but the heights do not add up. Its behavior for multiple histograms is actually not documented, so maybe it is a *feature*.
# This example is from the zoo examples.
#
# <img  src="Selection_037.png" align="left"/>

# %%
io['output.histogram(namevalue)'].plot(horizontal=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
io['output.histogram(width)'].plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
